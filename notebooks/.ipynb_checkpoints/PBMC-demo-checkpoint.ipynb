# %%
# Head to the main JIND directory
# %cd ../
# Make sure JIND is installed
# !pip install -e .
# Out:
# /srv/data/mohit/seq-rna/JIND

# %%
import numpy as np
import sys, os, pdb
import pandas as pd
import argparse
import torch
from jind import JindLib
from matplotlib import pyplot as plt
import argparse
from datetime import datetime

# %%
# Path to source batch
train_path = "data/train.pkl"
# Path to target batch
test_path = "data/test.pkl"
# Column containing cell-types
lname = "labels" 

train_batch = pd.read_pickle(train_path)
test_batch = pd.read_pickle(test_path)

# %%
train_mat = train_batch.drop(lname, axis=1)
train_labels = train_batch[lname]

test_mat = test_batch.drop(lname, axis=1)
test_labels = test_batch[lname]

path = os.path.dirname(train_path) + "/JIND"

obj = JindLib(train_mat, train_labels, path=path)
mat = train_mat.values
mat_round = np.rint(mat)
error = np.mean(np.abs(mat - mat_round))
if error == 0:
    print("Data is int")
    obj.preprocess()

# %%
obj.dim_reduction(5000, 'Var')

train_config = {'val_frac': 0.2, 'seed': 0, 'batch_size': 128, 'cuda': False,
                'epochs': 15}

obj.train_classifier(config=train_config, cmat=True)
# Out:
# Variance based reduction ...
# Epoch 0 Train: 0.4535: 100%|██████████| 51/51 [00:00<00:00, 57.40it/s]
# Epoch 1 Train: 0.044:  18%|█▊        | 9/51 [00:00<00:00, 89.34it/s]
# Validation Accuracy 0.9772
# Epoch 1 Train: 0.0368: 100%|██████████| 51/51 [00:00<00:00, 92.67it/s]
# Epoch 2 Train: 0.0198:  22%|██▏       | 11/51 [00:00<00:00, 106.65it/s]
# Validation Accuracy 0.9728
# Epoch 2 Train: 0.019: 100%|██████████| 51/51 [00:00<00:00, 101.09it/s]
# Epoch 3 Train: 0.0109:  20%|█▉        | 10/51 [00:00<00:00, 98.65it/s]
# Validation Accuracy 0.9821
# Epoch 3 Train: 0.0093: 100%|██████████| 51/51 [00:00<00:00, 106.31it/s]
# Epoch 4 Train: 0.0071:  20%|█▉        | 10/51 [00:00<00:00, 97.82it/s]
# Validation Accuracy 0.9821
# Epoch 4 Train: 0.0063: 100%|██████████| 51/51 [00:00<00:00, 105.59it/s]
# Epoch 5 Train: 0.0029:  20%|█▉        | 10/51 [00:00<00:00, 94.25it/s]
# Validation Accuracy 0.9809
# Epoch 5 Train: 0.0025: 100%|██████████| 51/51 [00:00<00:00, 95.64it/s]
# Epoch 6 Train: 0.0013:  22%|██▏       | 11/51 [00:00<00:00, 101.44it/s]
# Validation Accuracy 0.9790
# Epoch 6 Train: 0.0012: 100%|██████████| 51/51 [00:00<00:00, 93.52it/s]
# Epoch 7 Train: 0.0007:  20%|█▉        | 10/51 [00:00<00:00, 97.41it/s]
# Validation Accuracy 0.9796
# Epoch 7 Train: 0.0009: 100%|██████████| 51/51 [00:00<00:00, 96.72it/s]
# Epoch 8 Train: 0.0009:  18%|█▊        | 9/51 [00:00<00:00, 84.43it/s]
# Validation Accuracy 0.9815
# Epoch 8 Train: 0.0007: 100%|██████████| 51/51 [00:00<00:00, 88.69it/s]
# Epoch 9 Train: 0.0007:  20%|█▉        | 10/51 [00:00<00:00, 91.37it/s]
# Validation Accuracy 0.9790
# Epoch 9 Train: 0.0008: 100%|██████████| 51/51 [00:00<00:00, 86.37it/s]
# Epoch 10 Train: 0.0005:  20%|█▉        | 10/51 [00:00<00:00, 95.24it/s]
# Validation Accuracy 0.9809
# Epoch 10 Train: 0.0005: 100%|██████████| 51/51 [00:00<00:00, 94.21it/s]
# Epoch 11 Train: 0.0003:  22%|██▏       | 11/51 [00:00<00:00, 100.42it/s]
# Validation Accuracy 0.9802
# Epoch 11 Train: 0.0003: 100%|██████████| 51/51 [00:00<00:00, 98.41it/s]
# Epoch 12 Train: 0.0003:  20%|█▉        | 10/51 [00:00<00:00, 96.24it/s]
# Validation Accuracy 0.9815
# Epoch 12 Train: 0.0003: 100%|██████████| 51/51 [00:00<00:00, 95.04it/s]
# Epoch 13 Train: 0.0003:  20%|█▉        | 10/51 [00:00<00:00, 98.09it/s]
# Validation Accuracy 0.9809
# Epoch 13 Train: 0.0006: 100%|██████████| 51/51 [00:00<00:00, 95.99it/s]
# Epoch 14 Train: 0.0002:  20%|█▉        | 10/51 [00:00<00:00, 98.97it/s]
# Validation Accuracy 0.9796
# Epoch 14 Train: 0.0002: 100%|██████████| 51/51 [00:00<00:00, 99.08it/s]
# Validation Accuracy 0.9784
# Test Acc Pre 0.9821 Post 0.9389 Eff 0.9915 Filtered 0.0531

# %%
predicted_label1, log1 = obj.evaluate(test_mat, test_labels, frac=0.05, name="testcfmt.pdf", return_log=True)
# Out:
# Test Acc Pre 0.9549 Post 0.8079 Eff 0.9876 Filtered 0.1819

# %%
# Save object for later use
obj.to_pickle("JindLib_obj.pkl")

# %%
obj.remove_effect(train_mat, test_mat, train_config, test_labels)
# Out:
# Epoch 0 G Loss: 0.746 D Loss: 0.677: 100%|██████████| 58/58 [00:05<00:00, 10.46it/s]
#   0%|          | 0/58 [00:00<?, ?it/s]
# Evaluating....
# Test Acc Pre 0.9656 Post 0.9021 Eff 0.9851 Filtered 0.0842
# Epoch 1 G Loss: 0.715 D Loss: 0.686: 100%|██████████| 58/58 [00:05<00:00,  9.88it/s]
#   0%|          | 0/58 [00:00<?, ?it/s]
# Evaluating....
# Test Acc Pre 0.9676 Post 0.9088 Eff 0.9847 Filtered 0.0771
# Epoch 2 G Loss: 0.717 D Loss: 0.682: 100%|██████████| 58/58 [00:05<00:00,  9.73it/s]
# Evaluating....
# Test Acc Pre 0.9703 Post 0.9133 Eff 0.9864 Filtered 0.0741

# %%
predicted_label2, log2  = obj.evaluate(test_mat, test_labels, frac=0.05, name="testcfmtbr.pdf", test=True, return_log=True)
# Out:
# Test Acc Pre 0.9703 Post 0.9133 Eff 0.9864 Filtered 0.0741

# %%
train_config = {'val_frac': 0.1, 'seed': 0, 'batch_size': 32, 'cuda': False,
				'epochs': 10}
obj.ftune(test_mat, train_config)
# Out:
# Epoch 0 Train: 0.0001: 100%|██████████| 126/126 [00:01<00:00, 105.10it/s]
# Epoch 1 Train: 0.0:   9%|▊         | 11/126 [00:00<00:01, 100.01it/s]
# Validation Accuracy 1.0000
# Epoch 1 Train: 0.0: 100%|██████████| 126/126 [00:01<00:00, 101.76it/s]
# Epoch 2 Train: 0.0:   9%|▊         | 11/126 [00:00<00:01, 107.60it/s]
# Validation Accuracy 1.0000
# Epoch 2 Train: 0.0: 100%|██████████| 126/126 [00:01<00:00, 107.89it/s]
# Epoch 3 Train: 0.0:   9%|▊         | 11/126 [00:00<00:01, 103.84it/s]
# Validation Accuracy 1.0000
# Epoch 3 Train: 0.0: 100%|██████████| 126/126 [00:01<00:00, 104.52it/s]
# Epoch 4 Train: 0.0:   9%|▊         | 11/126 [00:00<00:01, 105.93it/s]
# Validation Accuracy 1.0000
# Epoch 4 Train: 0.0: 100%|██████████| 126/126 [00:01<00:00, 105.71it/s]
# Epoch 5 Train: 0.0:   9%|▊         | 11/126 [00:00<00:01, 106.73it/s]
# Validation Accuracy 1.0000
# Epoch 5 Train: 0.0: 100%|██████████| 126/126 [00:01<00:00, 100.47it/s]
# Epoch 6 Train: 0.0:   9%|▊         | 11/126 [00:00<00:01, 101.82it/s]
# Validation Accuracy 1.0000
# Epoch 6 Train: 0.0: 100%|██████████| 126/126 [00:01<00:00, 109.08it/s]
# Epoch 7 Train: 0.0:  10%|█         | 13/126 [00:00<00:00, 125.20it/s]
# Validation Accuracy 1.0000
# Epoch 7 Train: 0.0: 100%|██████████| 126/126 [00:01<00:00, 109.00it/s]
# Epoch 8 Train: 0.0:   9%|▊         | 11/126 [00:00<00:01, 101.23it/s]
# Validation Accuracy 1.0000
# Epoch 8 Train: 0.0: 100%|██████████| 126/126 [00:01<00:00, 102.28it/s]
# Epoch 9 Train: 0.0:   9%|▊         | 11/126 [00:00<00:01, 104.23it/s]
# Validation Accuracy 1.0000
# Epoch 9 Train: 0.0: 100%|██████████| 126/126 [00:01<00:00, 103.65it/s]
# Validation Accuracy 1.0000
# Test Acc Pre 1.0000 Post 1.0000 Eff 1.0000 Filtered 0.0000
# Test Acc Pre 0.9740 Post 0.9515 Eff 0.9847 Filtered 0.0337

# %%
predicted_label3, log3  = obj.evaluate(test_mat, test_labels, frac=0.05, name="testcfmtbrftune.pdf", test=True, return_log=True)
# Out:
# Test Acc Pre 0.9740 Post 0.9515 Eff 0.9847 Filtered 0.0337

# %%
# Use the model before self training for comparing the latent state learnt by JIND Adversarial Alignment
obj.set_test_model("BR")

# Latent Space before Alignmnet
obj.vis_latent(train_mat, train_labels, test_mat, test_labels, test=False)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 15476 samples in 0.107s...
# [t-SNE] Computed neighbors for 15476 samples in 5.839s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15476
# [t-SNE] Computed conditional probabilities for sample 2000 / 15476
# [t-SNE] Computed conditional probabilities for sample 3000 / 15476
# [t-SNE] Computed conditional probabilities for sample 4000 / 15476
# [t-SNE] Computed conditional probabilities for sample 5000 / 15476
# [t-SNE] Computed conditional probabilities for sample 6000 / 15476
# [t-SNE] Computed conditional probabilities for sample 7000 / 15476
# [t-SNE] Computed conditional probabilities for sample 8000 / 15476
# [t-SNE] Computed conditional probabilities for sample 9000 / 15476
# [t-SNE] Computed conditional probabilities for sample 10000 / 15476
# [t-SNE] Computed conditional probabilities for sample 11000 / 15476
# [t-SNE] Computed conditional probabilities for sample 12000 / 15476
# [t-SNE] Computed conditional probabilities for sample 13000 / 15476
# [t-SNE] Computed conditional probabilities for sample 14000 / 15476
# [t-SNE] Computed conditional probabilities for sample 15000 / 15476
# [t-SNE] Computed conditional probabilities for sample 15476 / 15476
# [t-SNE] Mean sigma: 2.230019
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.544357
# [t-SNE] KL divergence after 1000 iterations: 1.702229

# %%
# Latent Space after Alignment
obj.vis_latent(train_mat, train_labels, test_mat, test_labels, test=True)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 15476 samples in 0.119s...
# [t-SNE] Computed neighbors for 15476 samples in 7.057s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15476
# [t-SNE] Computed conditional probabilities for sample 2000 / 15476
# [t-SNE] Computed conditional probabilities for sample 3000 / 15476
# [t-SNE] Computed conditional probabilities for sample 4000 / 15476
# [t-SNE] Computed conditional probabilities for sample 5000 / 15476
# [t-SNE] Computed conditional probabilities for sample 6000 / 15476
# [t-SNE] Computed conditional probabilities for sample 7000 / 15476
# [t-SNE] Computed conditional probabilities for sample 8000 / 15476
# [t-SNE] Computed conditional probabilities for sample 9000 / 15476
# [t-SNE] Computed conditional probabilities for sample 10000 / 15476
# [t-SNE] Computed conditional probabilities for sample 11000 / 15476
# [t-SNE] Computed conditional probabilities for sample 12000 / 15476
# [t-SNE] Computed conditional probabilities for sample 13000 / 15476
# [t-SNE] Computed conditional probabilities for sample 14000 / 15476
# [t-SNE] Computed conditional probabilities for sample 15000 / 15476
# [t-SNE] Computed conditional probabilities for sample 15476 / 15476
# [t-SNE] Mean sigma: 1.846199
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 76.390984
# [t-SNE] KL divergence after 1000 iterations: 2.104474
