# %%
# Head to the main JIND directory
# %cd ../

# Make sure JIND is installed
# !pip install -e .
# Out:
# /srv/data/mohit/seq-rna/JIND

# %%
# Dowload data
# !wget -O data/PBMC.merged.h5ad ftp://ngs.sanger.ac.uk/production/teichmann/BBKNN/PBMC.merged.h5ad
# Out:
# --2020-10-14 10:08:56--  ftp://ngs.sanger.ac.uk/production/teichmann/BBKNN/PBMC.merged.h5ad
#            => ‘data/PBMC.merged.h5ad’
# Resolving ngs.sanger.ac.uk (ngs.sanger.ac.uk)... 193.62.203.79
# Connecting to ngs.sanger.ac.uk (ngs.sanger.ac.uk)|193.62.203.79|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /production/teichmann/BBKNN ... done.
# ==> SIZE PBMC.merged.h5ad ... 84227519
# ==> PASV ... done.    ==> RETR PBMC.merged.h5ad ... done.
# Length: 84227519 (80M) (unauthoritative)
#
# 100%[======================================>] 8,42,27,519 13.3MB/s   in 5.5s
#
# 2020-10-14 10:09:03 (14.6 MB/s) - ‘data/PBMC.merged.h5ad’ saved [84227519]

# %%
# Import Libraries
import scanpy as sc 
import pandas as pd
import numpy as np

# %%
adata = sc.read("data/PBMC.merged.h5ad")
adata # This prints all the attributes (columns) present in this object. We need to identify which one corresponds to cell type and batch (if available)
# Out:
# AnnData object with n_obs × n_vars = 15476 × 1199
#     obs: 'Sample', 'n_counts', 'n_genes', 'batch', 'louvain', 'anno', 'Method', 'Cell type'
#     var: 'GeneName-0', 'GeneID-0', 'GeneName-1', 'GeneID-1', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Cell type_colors', 'Method_colors', 'Sample_colors', 'anno_colors', 'louvain', 'louvain_colors', 'neighbors', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_umap', 'X_tsne'

# %%
data = adata.to_df() # Extracts gene expression matrix
data['batch'] = adata.obs['batch']
data['labels'] = adata.obs['Cell type']

# %%
types = data['batch'].unique()
source_batch = data[data['batch'] == types[0]].drop(["batch"], axis=1)
target_batch = data[data['batch'] == types[1]].drop(["batch"], axis=1)

# %%
source_batch.shape, target_batch.shape
# Out:
# ((8098, 1200), (7378, 1200))

# %%
import pandas as pd
from jind import JindLib

lname = "labels"

train_mat = source_batch.drop(lname, axis=1)
train_labels = source_batch[lname]

test_mat = target_batch.drop(lname, axis=1)
test_labels = target_batch[lname]

path = "./my_results"

obj = JindLib(train_mat, train_labels, path=path)
mat = train_mat.values
mat_round = np.rint(mat)
error = np.mean(np.abs(mat - mat_round))
if error == 0:
    print("Data is int")
    obj.preprocess()

obj.dim_reduction(5000, 'Var')

train_config = {'val_frac': 0.2, 'seed': 0, 'batch_size': 128, 'cuda': False,
                'epochs': 15}

obj.train_classifier(config=train_config, cmat=True)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# Variance based reduction ...
# Epoch 0 Train: 0.4542: 100%|██████████| 51/51 [00:00<00:00, 86.46it/s]
# Epoch 1 Train: 0.0409:  22%|██▏       | 11/51 [00:00<00:00, 102.09it/s]
# Validation Accuracy 0.9772
# Epoch 1 Train: 0.0365: 100%|██████████| 51/51 [00:00<00:00, 98.94it/s]
# Epoch 2 Train: 0.0223:  20%|█▉        | 10/51 [00:00<00:00, 95.98it/s]
# Validation Accuracy 0.9704
# Epoch 2 Train: 0.0178: 100%|██████████| 51/51 [00:00<00:00, 94.80it/s]
# Epoch 3 Train: 0.0089:  18%|█▊        | 9/51 [00:00<00:00, 87.86it/s]
# Validation Accuracy 0.9852
# Epoch 3 Train: 0.0084: 100%|██████████| 51/51 [00:00<00:00, 103.60it/s]
# Epoch 4 Train: 0.0073:  22%|██▏       | 11/51 [00:00<00:00, 103.46it/s]
# Validation Accuracy 0.9833
# Epoch 4 Train: 0.0063: 100%|██████████| 51/51 [00:00<00:00, 99.22it/s]
# Epoch 5 Train: 0.0026:  20%|█▉        | 10/51 [00:00<00:00, 91.04it/s]
# Validation Accuracy 0.9809
# Epoch 5 Train: 0.0022: 100%|██████████| 51/51 [00:00<00:00, 96.43it/s]
# Epoch 6 Train: 0.0013:  20%|█▉        | 10/51 [00:00<00:00, 98.57it/s]
# Validation Accuracy 0.9809
# Epoch 6 Train: 0.0012: 100%|██████████| 51/51 [00:00<00:00, 92.55it/s]
# Epoch 7 Train: 0.0007:  18%|█▊        | 9/51 [00:00<00:00, 88.95it/s]
# Validation Accuracy 0.9821
# Epoch 7 Train: 0.0009: 100%|██████████| 51/51 [00:00<00:00, 89.32it/s]
# Epoch 8 Train: 0.0011:  20%|█▉        | 10/51 [00:00<00:00, 98.95it/s]
# Validation Accuracy 0.9821
# Epoch 8 Train: 0.0008: 100%|██████████| 51/51 [00:00<00:00, 94.53it/s]
# Epoch 9 Train: 0.0007:  20%|█▉        | 10/51 [00:00<00:00, 96.96it/s]
# Validation Accuracy 0.9802
# Epoch 9 Train: 0.0007: 100%|██████████| 51/51 [00:00<00:00, 92.33it/s]
# Epoch 10 Train: 0.0004:  18%|█▊        | 9/51 [00:00<00:00, 84.50it/s]
# Validation Accuracy 0.9821
# Epoch 10 Train: 0.0005: 100%|██████████| 51/51 [00:00<00:00, 89.54it/s]
# Epoch 11 Train: 0.0004:  22%|██▏       | 11/51 [00:00<00:00, 102.01it/s]
# Validation Accuracy 0.9821
# Epoch 11 Train: 0.0003: 100%|██████████| 51/51 [00:00<00:00, 100.65it/s]
# Epoch 12 Train: 0.0003:  24%|██▎       | 12/51 [00:00<00:00, 111.14it/s]
# Validation Accuracy 0.9821
# Epoch 12 Train: 0.0003: 100%|██████████| 51/51 [00:00<00:00, 105.12it/s]
# Epoch 13 Train: 0.0003:  20%|█▉        | 10/51 [00:00<00:00, 93.56it/s]
# Validation Accuracy 0.9802
# Epoch 13 Train: 0.0006: 100%|██████████| 51/51 [00:00<00:00, 92.49it/s]
# Epoch 14 Train: 0.0002:  20%|█▉        | 10/51 [00:00<00:00, 97.90it/s]
# Validation Accuracy 0.9821
# Epoch 14 Train: 0.0002: 100%|██████████| 51/51 [00:00<00:00, 97.69it/s]
# Validation Accuracy 0.9815
# Test Acc Pre 0.9852 Post 0.9395 Eff 0.9915 Filtered 0.0525

# %%
predicted_label1, log1 = obj.evaluate(test_mat, test_labels, frac=0.05, name=None, return_log=True)
train_config = {'seed': 0, 'batch_size': 512, 'cuda': False,
                'epochs': 20}

obj.remove_effect(train_mat, test_mat, train_config, test_labels)

predicted_label2, log2  = obj.evaluate(test_mat, test_labels, frac=0.05, name=None, test=True, return_log=True)
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# Test Acc Pre 0.9639 Post 0.7960 Eff 0.9882 Filtered 0.1945
# Epoch 0 G Loss: 0.745 D Loss: 0.673: 100%|██████████| 40/40 [00:06<00:00,  6.51it/s]
# Evaluating....
# Epoch 1 G Loss: 0.737 D Loss: 0.691:   2%|▎         | 1/40 [00:00<00:07,  5.48it/s]
# Test Acc Pre 0.9664 Post 0.8897 Eff 0.9862 Filtered 0.0979
# Epoch 1 G Loss: 0.721 D Loss: 0.685: 100%|██████████| 40/40 [00:06<00:00,  6.09it/s]
# Evaluating....
# Epoch 2 G Loss: 0.739 D Loss: 0.684:   2%|▎         | 1/40 [00:00<00:06,  5.63it/s]
# Test Acc Pre 0.9709 Post 0.9070 Eff 0.9867 Filtered 0.0808
# Epoch 2 G Loss: 0.714 D Loss: 0.683: 100%|██████████| 40/40 [00:06<00:00,  5.96it/s]
# Evaluating....
# Test Acc Pre 0.9733 Post 0.9127 Eff 0.9880 Filtered 0.0762
# Test Acc Pre 0.9733 Post 0.9127 Eff 0.9880 Filtered 0.0762

# %%
train_config = {'val_frac': 0.1, 'seed': 0, 'batch_size': 32, 'cuda': False,
                'epochs': 10}
obj.ftune(test_mat, train_config)
predicted_label3, log3  = obj.evaluate(test_mat, test_labels, frac=0.05, name="testcfmtbrftune.pdf", test=True, return_log=True)
# Out:
# Epoch 0 Train: 0.0001: 100%|██████████| 130/130 [00:01<00:00, 104.83it/s]
# Epoch 1 Train: 0.0:   8%|▊         | 11/130 [00:00<00:01, 104.63it/s]
# Validation Accuracy 1.0000
# Epoch 1 Train: 0.0: 100%|██████████| 130/130 [00:01<00:00, 104.45it/s]
# Epoch 2 Train: 0.0:   9%|▉         | 12/130 [00:00<00:01, 114.94it/s]
# Validation Accuracy 1.0000
# Epoch 2 Train: 0.0: 100%|██████████| 130/130 [00:01<00:00, 103.39it/s]
# Epoch 3 Train: 0.0:   8%|▊         | 10/130 [00:00<00:01, 91.66it/s]
# Validation Accuracy 1.0000
# Epoch 3 Train: 0.0: 100%|██████████| 130/130 [00:01<00:00, 102.15it/s]
# Epoch 4 Train: 0.0:   8%|▊         | 11/130 [00:00<00:01, 109.72it/s]
# Validation Accuracy 1.0000
# Epoch 4 Train: 0.0: 100%|██████████| 130/130 [00:01<00:00, 108.09it/s]
# Epoch 5 Train: 0.0:   8%|▊         | 11/130 [00:00<00:01, 106.95it/s]
# Validation Accuracy 1.0000
# Epoch 5 Train: 0.0: 100%|██████████| 130/130 [00:01<00:00, 103.08it/s]
# Epoch 6 Train: 0.0:   8%|▊         | 11/130 [00:00<00:01, 108.34it/s]
# Validation Accuracy 1.0000
# Epoch 6 Train: 0.0: 100%|██████████| 130/130 [00:01<00:00, 107.00it/s]
# Epoch 7 Train: 0.0:   8%|▊         | 11/130 [00:00<00:01, 104.95it/s]
# Validation Accuracy 1.0000
# Epoch 7 Train: 0.0: 100%|██████████| 130/130 [00:01<00:00, 108.52it/s]
# Epoch 8 Train: 0.0:   8%|▊         | 10/130 [00:00<00:01, 98.47it/s]
# Validation Accuracy 1.0000
# Epoch 8 Train: 0.0: 100%|██████████| 130/130 [00:01<00:00, 105.45it/s]
# Epoch 9 Train: 0.0:   8%|▊         | 10/130 [00:00<00:01, 99.78it/s]
# Validation Accuracy 1.0000
# Epoch 9 Train: 0.0: 100%|██████████| 130/130 [00:01<00:00, 103.27it/s]
# Validation Accuracy 1.0000
# Test Acc Pre 1.0000 Post 1.0000 Eff 1.0000 Filtered 0.0000
# Test Acc Pre 0.9764 Post 0.9505 Eff 0.9859 Filtered 0.0359
